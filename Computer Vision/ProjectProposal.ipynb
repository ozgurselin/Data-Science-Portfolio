# %% [markdown]
# # **PROJECT PROPOSAL**
#
#
# Selin Ozgur

# %% [markdown]
# **Executive** **Summary:**

# %% [markdown]
# **Objective**

# %% [markdown]
# **Data Set**

# %% [markdown]
# **Project Pipeline**

# %% [markdown]
# **EDA**

# %% [markdown]
# **References**
